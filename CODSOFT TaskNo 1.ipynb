# %%
# STUDENT PERFORMANCE PREDICTION PROJECT
# TASK 1

import pandas as pd
import matplotlib.pyplot as plt

# ============================================
# STEP 1: LOAD DATASET
# ============================================

df = pd.read_csv("Student Performance Prediction.csv")

print("Dataset Loaded Successfully")
print(df.head(50))
# Out:
# Dataset Loaded Successfully
#     study_hours  attendance  sleep_hours  internet_usage  \
# 0             7          56            8               7
# 1             4          69            5               3
# 2            11          60            7               6
# 3             8          99            9               8
# 4             5          52            8               6
# 5             7          40            9              10
# 6            10          40            4              11
# 7             3          86            7               3
# 8             7          72            8               5
# 9            11          77            4               9
# 10           11          64            8               8
# 11            8          65            5               6
# 12            5          52            6               9
# 13            4          98            9               2
# 14            8          67            8              11
# 15            8          72            7               9
# 16            3          76            8              10
# 17            6          80            8              10
# 18            5          69            8               6
# 19            2          96            8               9
# 20            8          88            7               4
# 21            6          87            7               5
# 22            2          47            8               2
# 23            5          88            6               3
# 24            1          86            8               1
# 25           10          95            9               4
# 26            6          40            9               2
# 27            9          51            7               2
# 28            1          44            9               1
# 29           11          63            9              10
# 30           11          45            5               2
# 31           10          64            8               4
# 32            3          40            8               6
# 33            7          64            8               7
# 34            4          40            8               7
# 35            9          71            4               7
# 36            3          81            8               4
# 37            5          81            7               5
# 38            3          42            7              11
# 39            7          88            4               3
# 40            5          58            8               1
# 41            9          99            6               8
# 42            7          82            8              10
# 43            2          68            7              11
# 44            4          89            5               7
# 45            9          41            9               9
# 46            2          48            5              10
# 47           10          95            6               4
# 48            9          56            8               5
# 49           10          99            4               5
#
#     assignments_completed  previous_score  exam_score placement_status
# 0                      10              62      100.00           Placed
# 1                       8              56      100.00           Placed
# 2                      10              45      100.00           Placed
# 3                       4              55       90.17           Placed
# 4                       8              40       78.82           Placed
# 5                       0              60       72.33           Placed
# 6                       9              50       98.12           Placed
# 7                       7              85      100.00           Placed
# 8                      18              48       96.81           Placed
# 9                      15              69      100.00           Placed
# 10                     12              76      100.00           Placed
# 11                      4              87      100.00           Placed
# 12                     17              89       95.36           Placed
# 13                      8              70      100.00           Placed
# 14                      3              56       83.49           Placed
# 15                     13              87      100.00           Placed
# 16                      6              36       63.26       Not Placed
# 17                     11              47       91.89           Placed
# 18                      6              45       73.69           Placed
# 19                     10              46       77.59           Placed
# 20                     14              67      100.00           Placed
# 21                      6              56       77.19           Placed
# 22                     19              87       98.66           Placed
# 23                     16              43      100.00           Placed
# 24                      4              78       91.65           Placed
# 25                      7              41      100.00           Placed
# 26                      9              51       95.60           Placed
# 27                      5              95      100.00           Placed
# 28                     20              44       76.12           Placed
# 29                      1              72       96.59           Placed
# 30                      4              93      100.00           Placed
# 31                      9              73      100.00           Placed
# 32                      2              85       75.73           Placed
# 33                     12              80       98.68           Placed
# 34                     15              59       63.20       Not Placed
# 35                     14              61      100.00           Placed
# 36                      1              64       79.70           Placed
# 37                      2              64       63.65       Not Placed
# 38                     19              77       78.22           Placed
# 39                     17              68      100.00           Placed
# 40                     19              67      100.00           Placed
# 41                     19              66      100.00           Placed
# 42                     14              92      100.00           Placed
# 43                      4              76       55.39       Not Placed
# 44                     10              46       90.41           Placed
# 45                      2              75       86.67           Placed
# 46                      8              57       66.93       Not Placed
# 47                      6              92      100.00           Placed
# 48                      1              63      100.00           Placed
# 49                     14              77      100.00           Placed

# %%
#STEP 2: Understanding the Data Structure

print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (10000, 8)
# Index(['study_hours', 'attendance', 'sleep_hours', 'internet_usage',
#        'assignments_completed', 'previous_score', 'exam_score',
#        'placement_status'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB
# None

# %%
# STEP 3: Summary Statistics

print(df.describe())
print(df[[
    "study_hours",
    "attendance",
    "sleep_hours",
    "internet_usage",
    "assignments_completed",
    "previous_score",
    "exam_score",
    "placement_status"
]].describe())
print(df['sleep_hours'].value_counts())
print(df['placement_status'].value_counts())
# Out:
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# min        1.000000     40.00000      4.000000        1.000000
# 25%        3.000000     55.00000      5.000000        3.000000
# 50%        6.000000     70.00000      6.500000        6.000000
# 75%        9.000000     85.00000      8.000000        9.000000
# max       11.000000    100.00000      9.000000       11.000000
#
#        assignments_completed  previous_score    exam_score
# count           10000.000000     10000.00000  10000.000000
# mean                9.988400        64.91100     86.704207
# std                 6.034145        17.50302     15.058383
# min                 0.000000        35.00000     26.670000
# 25%                 5.000000        50.00000     76.727500
# 50%                10.000000        65.00000     92.120000
# 75%                15.000000        80.00000    100.000000
# max                20.000000        95.00000    100.000000
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# min        1.000000     40.00000      4.000000        1.000000
# 25%        3.000000     55.00000      5.000000        3.000000
# 50%        6.000000     70.00000      6.500000        6.000000
# 75%        9.000000     85.00000      8.000000        9.000000
# max       11.000000    100.00000      9.000000       11.000000
#
#        assignments_completed  previous_score    exam_score
# count           10000.000000     10000.00000  10000.000000
# mean                9.988400        64.91100     86.704207
# std                 6.034145        17.50302     15.058383
# min                 0.000000        35.00000     26.670000
# 25%                 5.000000        50.00000     76.727500
# 50%                10.000000        65.00000     92.120000
# 75%                15.000000        80.00000    100.000000
# max                20.000000        95.00000    100.000000
# sleep_hours
# 5    1697
# 9    1679
# 7    1677
# 4    1660
# 8    1644
# 6    1643
# Name: count, dtype: int64
# placement_status
# Placed        8356
# Not Placed    1644
# Name: count, dtype: int64

# %%
#STEP 4: Checking for Missing Values
print(df.isnull())
"DROP DUPLICATES"
print(df.drop_duplicates())
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0           False       False        False           False
# 1           False       False        False           False
# 2           False       False        False           False
# 3           False       False        False           False
# 4           False       False        False           False
# ...           ...         ...          ...             ...
# 9995        False       False        False           False
# 9996        False       False        False           False
# 9997        False       False        False           False
# 9998        False       False        False           False
# 9999        False       False        False           False
#
#       assignments_completed  previous_score  exam_score  placement_status
# 0                     False           False       False             False
# 1                     False           False       False             False
# 2                     False           False       False             False
# 3                     False           False       False             False
# 4                     False           False       False             False
# ...                     ...             ...         ...               ...
# 9995                  False           False       False             False
# 9996                  False           False       False             False
# 9997                  False           False       False             False
# 9998                  False           False       False             False
# 9999                  False           False       False             False
#
# [10000 rows x 8 columns]
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# 2                        10              45      100.00           Placed
# 3                         4              55       90.17           Placed
# 4                         8              40       78.82           Placed
# ...                     ...             ...         ...              ...
# 9995                      8              88       69.31       Not Placed
# 9996                      4              87      100.00           Placed
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# 9999                     16              52       78.96           Placed
#
# [10000 rows x 8 columns]
